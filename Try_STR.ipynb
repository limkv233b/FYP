# %%
# !git clone https://github.com/ku21fan/STR-Fewer-Labels  # clone repo
# %cd STR-Fewer-Labels
# !git reset --hard
# Out:
# Cloning into 'STR-Fewer-Labels'...
# remote: Enumerating objects: 152, done.
# remote: Counting objects: 100% (152/152), done.
# remote: Compressing objects: 100% (126/126), done.
# remote: Total 152 (delta 73), reused 52 (delta 18), pack-reused 0
# Receiving objects: 100% (152/152), 1.63 MiB | 6.39 MiB/s, done.
# Resolving deltas: 100% (73/73), done.
# /content/STR-Fewer-Labels
# HEAD is now at 9ca8c5e Update README.md

# %%
# !pip3 install lmdb pillow torchvision nltk natsort fire tensorboard tqdm
# Out:
# ...
#      |████████████████████████████████| 87 kB 5.1 MB/s
# ...
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115942 sha256=04e1c632b2811e271df7d548e1d5accb540b45192c10e34fbc94b0d6222d0396
#   Stored in directory: /root/.cache/pip/wheels/8a/67/fb/2e8a12fa16661b9d5af1f654bd199366799740a85c64981226
# Successfully built fire
# ...

# %%
# %cd demo_image
# !wget -O 24hATM.jpg https://cvit.iiit.ac.in/images/Projects/SceneTextUnderstanding/I1.jpg
# !wget -O chanel.jpg https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSPnHSR1tFWjvJUS966M8H4v97FCFmqOZEs1A&usqp=CAU
# !wget -O middleBrough.jpg https://miro.medium.com/max/800/1*OudZ3NOumwUhqtSTLgktkw.jpeg
# !wget -O starbucks.jpg https://www.pymnts.com/wp-content/uploads/2020/01/starbucks-kevinjohnson-news-retail-globalcoffeealliance.jpg
# %cd -

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !cp /content/gdrive/My\ Drive/pretrained_model.zip /content/STR-Fewer-Labels
# !cp /content/gdrive/My\ Drive/data_CVPR2021.zip /content/STR-Fewer-Labels
# !cp /content/gdrive/My\ Drive/TRBA-PR.pth /content/STR-Fewer-Labels
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # New Section

# %%
# !unzip pretrained_model.zip
# Out:
# Archive:  pretrained_model.zip
# ...
# mapname:  conversion of  failed
#  extracting: CRNN-PR.pth
#  extracting: TRBA-PL.pth
#  extracting: TRBA-PR.pth
#  extracting: CRNN-PL.pth
#  extracting: TRBA-Aug.pth
#  extracting: CRNN-Aug.pth
#  extracting: CRNN-Baseline-real.pth
#  extracting: TRBA-Baseline-real.pth
#  extracting: CRNN-Baseline-synth.pth
#  extracting: TRBA-Baseline-synth.pth

# %%
# !unzip data_CVPR2021.zip
# Out:
# Archive:  data_CVPR2021.zip
#    creating: data_CVPR2021/
#    creating: data_CVPR2021/evaluation/
#    creating: data_CVPR2021/evaluation/addition/
#    creating: data_CVPR2021/evaluation/addition/5.COCO/
#   inflating: data_CVPR2021/evaluation/addition/5.COCO/lock.mdb
#   inflating: data_CVPR2021/evaluation/addition/5.COCO/data.mdb
#    creating: data_CVPR2021/evaluation/addition/8.ArT/
#   inflating: data_CVPR2021/evaluation/addition/8.ArT/lock.mdb
#   inflating: data_CVPR2021/evaluation/addition/8.ArT/data.mdb
#    creating: data_CVPR2021/evaluation/addition/9.LSVT/
#   inflating: data_CVPR2021/evaluation/addition/9.LSVT/data.mdb
#   inflating: data_CVPR2021/evaluation/addition/9.LSVT/lock.mdb
#    creating: data_CVPR2021/evaluation/addition/11.ReCTS/
#   inflating: data_CVPR2021/evaluation/addition/11.ReCTS/lock.mdb
#   inflating: data_CVPR2021/evaluation/addition/11.ReCTS/data.mdb
#    creating: data_CVPR2021/evaluation/addition/7.Uber/
# ...

# %%
# %%time
# !python3 demo.py --model_name TRBA --image_folder demo_image/ --saved_model TRBA-PR.pth
# Out:
# # of tokens and characters: 99
# model input parameters 32 100 20 3 512 256 99 25 TPS ResNet BiLSTM Attn
# loading pretrained model from TRBA-PR.pth
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# demo_image/1.png         	Coca-Cola                	0.9006
# demo_image/2.png         	hire                     	0.3716
# ...

# %%
# %%time
# !python3 demo.py --model_name TRBA --image_folder demo_image/ --saved_model TRBA-Baseline-real.pth
# Out:
# # of tokens and characters: 99
# model input parameters 32 100 20 3 512 256 99 25 TPS ResNet BiLSTM Attn
# loading pretrained model from TRBA-Baseline-real.pth
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# demo_image/1.png         	Coca-Cola                	0.9999
# demo_image/2.png         	Hire                     	0.8613
# ...

# %%
# %%time
# !python3 demo.py --model_name TRBA --image_folder demo_image/ --saved_model TRBA-Baseline-synth.pth
# Out:
# # of tokens and characters: 99
# model input parameters 32 100 20 3 512 256 99 25 TPS ResNet BiLSTM Attn
# loading pretrained model from TRBA-Baseline-synth.pth
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# demo_image/1.png         	(ccaloola.               	0.0423
# demo_image/2.png         	Line                     	0.8685
# ...

# %%
# %%time
# !python3 demo.py --model_name TRBA --image_folder demo_image/ --saved_model TRBA-PL.pth
# Out:
# # of tokens and characters: 99
# model input parameters 32 100 20 3 512 256 99 25 TPS ResNet BiLSTM Attn
# loading pretrained model from TRBA-PL.pth
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# demo_image/1.png         	Coca-Cola                	0.8905
# demo_image/2.png         	hire                     	0.7226
# ...

# %%
# %%time
# !python3 demo.py --model_name CRNN --image_folder demo_image/ --saved_model CRNN-PR.pth
# Out:
# # of tokens and characters: 98
# No Transformation module specified
# model input parameters 32 100 20 3 512 256 98 25 None VGG BiLSTM CTC
# loading pretrained model from CRNN-PR.pth
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# demo_image/1.png         	CocaCola                 	0.4518
# ...

# %%
# %%time
# !python3 demo.py --model_name CRNN --image_folder demo_image/ --saved_model CRNN-Baseline-real.pth
# Out:
# # of tokens and characters: 98
# No Transformation module specified
# model input parameters 32 100 20 3 512 256 98 25 None VGG BiLSTM CTC
# loading pretrained model from CRNN-Baseline-real.pth
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# demo_image/1.png         	CocaCola                 	0.6716
# ...

# %%
# %%time
# !python3 demo.py --model_name CRNN --image_folder demo_image/ --saved_model CRNN-Baseline-synth.pth
# Out:
# # of tokens and characters: 98
# No Transformation module specified
# model input parameters 32 100 20 3 512 256 98 25 None VGG BiLSTM CTC
# loading pretrained model from CRNN-Baseline-synth.pth
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# demo_image/1.png         	CcuGolh.                 	0.0051
# ...

# %%
# !mkdir data_CVPR2021
# !mkdir data_CVPR2021/evaluation
# !mkdir data_CVPR2021/evaluation/benchmark
# !cp -r /content/gdrive/My\ Drive/recognition_test_sets/recognition_test_sets/IIIT5K_3000/data.mdb /content/STR-Fewer-Labels/data_CVPR2021/evaluation/benchmark/IIIT5K_3000/data.lmdb
# Out:
# mkdir: cannot create directory ‘data_CVPR2021’: File exists
# mkdir: cannot create directory ‘data_CVPR2021/evaluation’: File exists
# mkdir: cannot create directory ‘data_CVPR2021/evaluation/benchmark’: File exists
# cp: cannot create regular file '/content/STR-Fewer-Labels/data_CVPR2021/evaluation/benchmark/IIIT5K_3000/data.lmdb': No such file or directory

# %%
# %%time
# !python3 test.py --eval_type benchmark --model_name CRNN --saved_model CRNN-PR.pth
# Out:
# # of tokens and characters: 98
# No Transformation module specified
# model input parameters 32 100 20 3 512 256 98 25 None VGG BiLSTM CTC
# loading pretrained model from CRNN-PR.pth
# --------------------------------------------------------------------------------
# dataset_root:    data_CVPR2021/evaluation/benchmark/IIIT5k_3000	 dataset: /
# sub-directory:	/.	 num samples: 3000
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Acc 89.83
# --------------------------------------------------------------------------------
# ...

# %%
# %%time
# !python3 test.py --eval_type benchmark --model_name TRBA --saved_model TRBA-PR.pth
# Out:
# # of tokens and characters: 99
# model input parameters 32 100 20 3 512 256 99 25 TPS ResNet BiLSTM Attn
# loading pretrained model from TRBA-PR.pth
# --------------------------------------------------------------------------------
# dataset_root:    data_CVPR2021/evaluation/benchmark/IIIT5k_3000	 dataset: /
# sub-directory:	/.	 num samples: 3000
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Acc 95.00
# --------------------------------------------------------------------------------
# dataset_root:    data_CVPR2021/evaluation/benchmark/SVT	 dataset: /
# ...

# %%
# %%time
# !python3 test.py --eval_type benchmark --model_name TRBA --saved_model TRBA-Baseline-real.pth
# Out:
# # of tokens and characters: 99
# model input parameters 32 100 20 3 512 256 99 25 TPS ResNet BiLSTM Attn
# loading pretrained model from TRBA-Baseline-real.pth
# --------------------------------------------------------------------------------
# dataset_root:    data_CVPR2021/evaluation/benchmark/IIIT5k_3000	 dataset: /
# sub-directory:	/.	 num samples: 3000
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Acc 93.63
# --------------------------------------------------------------------------------
# dataset_root:    data_CVPR2021/evaluation/benchmark/SVT	 dataset: /
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0 python3 train.py --model_name CRNN --exp_name CRNN_aug --Aug Crop90-Rot15
# Out:
# Command line input: CUDA_VISIBLE_DEVICES=0 python train.py --model_name CRNN --exp_name CRNN_aug --Aug Crop90-Rot15
# --------------------------------------------------------------------------------
# dataset_root: data_CVPR2021/training/label/
# select_data: ['1.SVT', '2.IIIT', '3.IC13', '4.IC15', '5.COCO', '6.RCTW17', '7.Uber', '8.ArT', '9.LSVT', '10.MLT19', '11.ReCTS']
# batch_ratio: [0.091, 0.091, 0.091, 0.091, 0.091, 0.091, 0.091, 0.091, 0.091, 0.091, 0.091]
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:1249: UserWarning: Argument resample is deprecated and will be removed since v0.10.0. Please, use interpolation instead
#   "Argument resample is deprecated and will be removed since v0.10.0. Please, use interpolation instead"
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:288: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
# ...
